# %% [markdown]
# # Microestructura y Sistemas de Trading

# %% [markdown]
# ## Notas de Administracion Activa

# %%
# Remover todos los objetos del "Environment"
rm(list = ls())

# los 0s aceptados antes de expresas una cifra en notaci?n cient?fica
options("scipen"=100, "digits"=4)

# Cargas librer?as a utilizar
suppressMessages(library(xlsx)) # Graficas interactivas
#suppressMessages(library(Quandl)) # Descargar Precios
#suppressMessages(library(ROI))    # Optimizacion para portafolio
#suppressMessages(library(knitr))  # Opciones de documentaci?n + c?digo
#suppressMessages(library(xlsx))   # Leer archivos XLSx
#suppressMessages(library(kableExtra)) # Tablas en HTML
#suppressMessages(library(PortfolioAnalytics)) # Teor?a Moderna de Portafolios

options(knitr.table.format = "html")
# Out:
# Error in library(Quandl): there is no package called ‘Quandl’
# Traceback:
#
# 1. suppressMessages(library(Quandl))
# 2. withCallingHandlers(expr, message = function(c) invokeRestart("muffleMessage"))
# 3. library(Quandl)
# 4. stop(txt, domain = NA)

# %%
tk <- as.data.frame(read.csv(file = "IAK_holdings.csv",header = FALSE, sep = ","))
cs <- c("date", "adj_close")

# %%
class(tk)
# Out:
# [1] "data.frame"

# %%
tk
# Out:
#     V1                         V2
# 1   iShares U.S. Insurance ETF
# 2   Inception Date             01-may-2006
# 3   Fund Holdings as of        06-sep-2018
# 4   Total Net Assets           116,250,833.46
# 5                              1,750,000.00
# 6   Stock                      -
# 7   Bond                       -
# 8   Cash                       -
# 9   Other                      -
# 10
# 11  Ticker                     Nombre
# 12  Clase de activo            Peso (%)
# 13  Precio                     Acciones
# 14  Valor de mercado           Valor nominal
# 15  Sector                     SEDOL
# 16  ISIN                       Bolsa de valores
# 17  CB                         CHUBB LTD
# 18  Equity                     8.72
# 19  137.34                     73,813.00
# 20  10,137,477.42              10,137,477.42
# 21  Financieros                B3BQMF6
# 22  CH0044328745               New York Stock Exchange Inc.
# 23  AIG                        AMERICAN INTERNATIONAL GROUP INC
# 24  Equity                     6.77
# 25  53.90                      145,957.00
# 26  7,867,082.30               7,867,082.30
# 27  Financieros                2027342
# 28  US0268747849               New York Stock Exchange Inc.
# 29  MET                        METLIFE INC
# 30  Equity                     6.52
# ... ...                        ...
# 378 Cash                       0.18
# 379 100.00                     206,743.00
# 380 206,742.99                 206,742.99
# 381 Efectivo y Derivados       -
# 382 -                          -
# 383 FFG                        FBL FINANCIAL GROUP INC CLASS A
# 384 Equity                     0.18
# 385 80.30                      2,536.00
# 386 203,640.80                 203,640.80
# 387 Financieros                2329082
# 388 US30239F1066               New York Stock Exchange Inc.
# 389 NWLI                       NATIONAL WESTERN LIFE GROUP INC CL
# 390 Equity                     0.16
# 391 321.60                     588.00
# 392 189,100.80                 189,100.80
# 393 Financieros                BYSPYB3
# 394 US6385171029               NASDAQ
# 395 STFC                       STATE AUTO FINANCIAL CORP
# 396 Equity                     0.12
# 397 30.94                      4,390.00
# 398 135,826.60                 135,826.60
# 399 Financieros                2841898
# 400 US8557071052               NASDAQ
# 401 BLKFDS                     BLK CSH FND TREASURY SL AGENCY
# 402 Money Market               0.10
# 403 1.00                       111,071.00
# 404 111,071.48                 111,071.48
# 405 Efectivo y Derivados       -
# 406 US0669224778               -
# 407
