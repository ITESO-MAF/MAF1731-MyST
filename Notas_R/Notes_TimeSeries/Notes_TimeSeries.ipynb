# %%
library(fGarch)

# %%
# Returns for ticker: intc (Intel) and sp (S&P500)

# %%
data <- read.table("m-intcsp7309.txt", header=T)
head(data)
# Out:
#   date     intc      sp
# 1 19730131  0.010050 -0.017111
# 2 19730228 -0.139303 -0.037490
# 3 19730330  0.069364 -0.001433
# 4 19730430  0.086486 -0.040800
# 5 19730531 -0.104478 -0.018884
# 6 19730629  0.133333 -0.006575

# %%
# intc <- log(data$intc+1)
acf(data$intc)
# acf(intc^2)
# pacf(intc^2)
# Out:
# Plot with title “Series  data$intc”

# %%
acf(log(data$intc+1))
# Out:
# Plot with title “Series  log(data$intc + 1)”

# %%
acf(intc^2)
# Out:
# Plot with title “Series  intc^2”
