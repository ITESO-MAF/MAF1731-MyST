# %% [markdown]
# <img src="http://oci02.img.iteso.mx/identidad_de_instancia_2018/ITESO/Logos%20ITESO/Logo-ITESO-Principal.jpg">

# %% [markdown]
#   ---

# %% [markdown]
# <center> <font color= #004A94> <font size = 5> Ingeniería Financiera | ITESO </font> <br> <br>

# %% [markdown]
# <center> <font color= #004A94> <font size = 6> Microestructura y Sistemas de Trading </font> <br> <br>

# %% [markdown]
# <center> <font color=#42c29b><font size=5> Laboratorio 2 <br> <br> Titulo de laboratorio </font> <br> <br>

# %% [markdown]
# <center> <font color=#004A94><font size=4> I.F. Nombre Nombre Apellido Apellido | correo@iteso.mx </font> <br> <br>

# %% [markdown]
#   ---

# %% [markdown]
# # Abstract

# %% [markdown]
# En este trabajo ...

# %% [markdown]
# # Modulos y dependencias

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Análisis de histórico de cuenta

# %% [markdown]
# En este trabajo ...

# %% [markdown]
# # Medidas de atribución al desempeño

# %% [markdown]
# En este trabajo ...

# %% [markdown]
# # Behavioral Finance

# %% [markdown]
# En este trabajo ...
